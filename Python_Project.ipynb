# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv')
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# # Task 1

# %%
#Display number of rows and columns in data set
df.shape
# Out:
# (4803, 20)

# %%
#Display genre and title of the first 50 movies
df[['genres','title']].head(50)
# Out:
#                                                genres  \
# 0   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1   [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3   [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5   [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6   [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8   [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 13  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 14  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 15  [{"id": 12, "name": "Adventure"}, {"id": 10751...
# ...

# %% [markdown]
# # Task 2

# %%
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
#Replacing Null Values
df.homepage=df.homepage.fillna('Not Defined')
df.overview=df.overview.fillna('Not Defined')
df.tagline=df.tagline.fillna('Not Defined')
df.release_date=df.release_date.fillna(df.release_date.mode()[0])
df.runtime=df.runtime.fillna(df.runtime.median())

# %%
df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# # Task 3

# %%
#Movie category that have budget more then $220,000
cond=df['budget']>220000
t3=df[cond]
print(t3['genres'])
print('genere:',t3['genres'].size)
# Out:
# 0       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1       [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3       [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#                               ...
# 4664    [{"id": 18, "name": "Drama"}, {"id": 28, "name...
# 4666    [{"id": 10769, "name": "Foreign"}, {"id": 99, ...
# 4670    [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 4720                        [{"id": 18, "name": "Drama"}]
# 4758    [{"id": 53, "name": "Thriller"}, {"id": 878, "...
# Name: genres, Length: 3183, dtype: object
# genere: 3183

# %% [markdown]
# # Task 4

# %%
#Movie category that have revenue more then $961,000,000
cond=df['revenue']>961000000
t4=df[cond]
print(t4['genres'])
print('genere:',t4['genres'].size)
# Out:
# 0      [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3      [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 7      [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 12     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 16     [{"id": 878, "name": "Science Fiction"}, {"id"...
# 17     [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 25     [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 26     [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 28     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 29     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 31     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 32     [{"id": 10751, "name": "Family"}, {"id": 14, "...
# 36     [{"id": 878, "name": "Science Fiction"}, {"id"...
# 42     [{"id": 16, "name": "Animation"}, {"id": 10751...
# 44                        [{"id": 28, "name": "Action"}]
# 52     [{"id": 28, "name": "Action"}, {"id": 878, "na...
# ...

# %% [markdown]
# # Task 5

# %%
#Droping the rows where Value is zero for both revenue and budget 
cond=(df['budget']==0)|(df['revenue']==0)
t5=df[cond]
df.drop(index=t5.index,inplace=True)
shape=df.shape
print(f'Rows after droping: {shape[0]}')
# Out:
# Rows after droping: 3229

# %% [markdown]
# # Task 6

# %%
#Top 10 movie with the highest revenue and top 10 movie with the least budget
t6_1=df[['title','revenue']].sort_values('revenue',ascending=False).head(10)
t6_2=df[['title','budget']].sort_values('budget',ascending=True).head(10)
fig,axs=plt.subplots(2,1,figsize=(15,10))
sns.barplot(data=t6_1,x='title',y='revenue',ax=axs[0])
axs[0].set_title('Top 10 movie with the highest revenue')
sns.barplot(data=t6_2,x='title',y='budget',ax=axs[1])
axs[1].set_title('Top 10 movie with the least budget')
# Out:
# Text(0.5, 1.0, 'Top 10 movie with the least budget')

# %% [markdown]
# # Task 7

# %%
#Corelation Between budget and Popularity 
plt.figure(figsize=(15,5))
sns.scatterplot(data=df,x='budget',y='popularity')
plt.title('Corelation B/W polpularity and budget')
df.budget.corr(df.popularity)
# Out:
# 0.4319901360079751

# %% [markdown]
# Budget and popularities are weekely corelated

# %% [markdown]
# # Task 8

# %%
#name of all production companies along with the number of movies they produced
t8=pd.pivot_table(data=df,values='id',index='production_companies',aggfunc='count')
t8.sort_values(by='id',ascending=False)
# Out:
#                                                     id
# production_companies
# [{"name": "Paramount Pictures", "id": 4}]           48
# []                                                  41
# [{"name": "Universal Pictures", "id": 33}]          35
# [{"name": "New Line Cinema", "id": 12}]             29
# [{"name": "Columbia Pictures", "id": 5}]            28
# ...                                                 ..
# [{"name": "Ingenious Film Partners", "id": 289}...   1
# [{"name": "Ingenious Film Partners", "id": 289}...   1
# [{"name": "Ingenious Film Partners", "id": 289}...   1
# [{"name": "Ingenious Film Partners", "id": 289}...   1
# [{"name": "icon", "id": 4096}]                       1
#
# [2633 rows x 1 columns]

# %% [markdown]
# # Task 9

# %%
#Top 25 production companies based on number of film
t8.sort_values(by='id',ascending=False).head(25)
# Out:
#                                                     id
# production_companies
# [{"name": "Paramount Pictures", "id": 4}]           48
# []                                                  41
# [{"name": "Universal Pictures", "id": 33}]          35
# [{"name": "New Line Cinema", "id": 12}]             29
# [{"name": "Columbia Pictures", "id": 5}]            28
# [{"name": "Twentieth Century Fox Film Corporati...  25
# [{"name": "Metro-Goldwyn-Mayer (MGM)", "id": 84...  24
# [{"name": "Warner Bros.", "id": 6194}]              24
# [{"name": "Walt Disney Pictures", "id": 2}]         18
# [{"name": "Touchstone Pictures", "id": 9195}]       15
# [{"name": "Columbia Pictures Corporation", "id"...  13
# [{"name": "Dimension Films", "id": 7405}]           13
# [{"name": "DreamWorks Animation", "id": 521}]       12
# [{"name": "Walt Disney Pictures", "id": 2}, {"n...  11
# [{"name": "United Artists", "id": 60}]              10
# [{"name": "Miramax Films", "id": 14}]                9
# ...

# %% [markdown]
# # Task 10

# %%
#Central tendency for Budget , revenue and runtime
t10=df.sort_values('revenue',ascending=False).head(500)
CT=t10.describe()
CT.drop(index=['count','std','min','max','25%','75%'],columns=['id','popularity','vote_average','vote_count'],inplace=True)
CT.rename(index={'50%':'median'},inplace=True)
t10.budget.mode()[0]
m=pd.DataFrame({'mode':[t10.budget.mode()[0],t10.revenue.mode()[0],t10.runtime.mode()[0]]},index=['budget','revenue','runtime'])
m=m.transpose()
CT=CT.append(m)
CT
# Out:
#              budget       revenue  runtime
# mean    103193736.0  4.585776e+08   118.72
# median   95000000.0  3.630016e+08   116.00
# mode    150000000.0  2.177643e+08   115.00

# %%
fig,ax=plt.subplots(1,3,figsize=(15,5))
sns.boxplot(data=t10,y='budget',ax=ax[0])
sns.boxplot(data=t10,y='revenue',ax=ax[1],color='r')
sns.boxplot(data=t10,y='runtime',ax=ax[2],color='g')
# Out:
# <AxesSubplot:ylabel='runtime'>

# %% [markdown]
# # Task 11

# %%
#Movies with above average runtime
cond=df.runtime>118.72
t11=df[cond]
t11[['title','runtime']]
# Out:
#                                          title  runtime
# 0                                       Avatar    162.0
# 1     Pirates of the Caribbean: At World's End    169.0
# 2                                      Spectre    148.0
# 3                        The Dark Knight Rises    165.0
# 4                                  John Carter    132.0
# ...                                        ...      ...
# 4511                                 Fireproof    122.0
# 4535                             Seven Samurai    207.0
# 4592                               Intolerance    197.0
# 4661                            The Big Parade    151.0
# 4720                     The Birth of a Nation    120.0
#
# [940 rows x 2 columns]
